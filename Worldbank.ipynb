# %% [markdown]
# ## **Import libraries**

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## **load the dataset**

# %%
df=pd.read_excel('WorldBank.xlsx')
df
# Out:
#       Country Name Country Code              Region IncomeGroup  Year  \
# 0      Afghanistan          AFG          South Asia  Low income  2018
# 1      Afghanistan          AFG          South Asia  Low income  2017
# 2      Afghanistan          AFG          South Asia  Low income  2016
# 3      Afghanistan          AFG          South Asia  Low income  2015
# 4      Afghanistan          AFG          South Asia  Low income  2014
# ...            ...          ...                 ...         ...   ...
# 12444     Zimbabwe          ZWE  Sub-Saharan Africa  Low income  1964
# 12445     Zimbabwe          ZWE  Sub-Saharan Africa  Low income  1963
# 12446     Zimbabwe          ZWE  Sub-Saharan Africa  Low income  1962
# 12447     Zimbabwe          ZWE  Sub-Saharan Africa  Low income  1961
# 12448     Zimbabwe          ZWE  Sub-Saharan Africa  Low income  1960
#
#        Birth rate, crude (per 1,000 people)  \
# 0                                       NaN
# ...

# %%
df.head()
# Out:
#   Country Name Country Code      Region IncomeGroup  Year  \
# 0  Afghanistan          AFG  South Asia  Low income  2018
# 1  Afghanistan          AFG  South Asia  Low income  2017
# 2  Afghanistan          AFG  South Asia  Low income  2016
# 3  Afghanistan          AFG  South Asia  Low income  2015
# 4  Afghanistan          AFG  South Asia  Low income  2014
#
#    Birth rate, crude (per 1,000 people)  Death rate, crude (per 1,000 people)  \
# 0                                   NaN                                   NaN
# 1                                33.211                                 6.575
# 2                                33.981                                 6.742
# 3                                34.809                                 6.929
# 4                                35.706                                 7.141
#
#    Electric power consumption (kWh per capita)     GDP (USD)  \
# 0                                          NaN  1.936300e+10
# ...

# %%
df.tail()
# Out:
#       Country Name Country Code              Region IncomeGroup  Year  \
# 12444     Zimbabwe          ZWE  Sub-Saharan Africa  Low income  1964
# 12445     Zimbabwe          ZWE  Sub-Saharan Africa  Low income  1963
# 12446     Zimbabwe          ZWE  Sub-Saharan Africa  Low income  1962
# 12447     Zimbabwe          ZWE  Sub-Saharan Africa  Low income  1961
# 12448     Zimbabwe          ZWE  Sub-Saharan Africa  Low income  1960
#
#        Birth rate, crude (per 1,000 people)  \
# 12444                                47.770
# 12445                                47.876
# 12446                                47.950
# 12447                                47.988
# 12448                                47.996
#
#        Death rate, crude (per 1,000 people)  \
# 12444                                13.083
# 12445                                13.419
# 12446                                13.762
# 12447                                14.104
# 12448                                14.441
#
# ...

# %%
df.columns
# Out:
# Index(['Country Name', 'Country Code', 'Region', 'IncomeGroup', 'Year',
#        'Birth rate, crude (per 1,000 people)',
#        'Death rate, crude (per 1,000 people)',
#        'Electric power consumption (kWh per capita)', 'GDP (USD)',
#        'GDP per capita (USD)',
#        'Individuals using the Internet (% of population)',
#        'Infant mortality rate (per 1,000 live births)',
#        'Life expectancy at birth (years)',
#        'Population density (people per sq. km of land area)',
#        'Unemployment (% of total labor force) (modeled ILO estimate)'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12449 entries, 0 to 12448
# Data columns (total 15 columns):
#  #   Column                                                        Non-Null Count  Dtype
# ---  ------                                                        --------------  -----
#  0   Country Name                                                  12449 non-null  object
#  1   Country Code                                                  12449 non-null  object
#  2   Region                                                        12449 non-null  object
#  3   IncomeGroup                                                   12449 non-null  object
#  4   Year                                                          12449 non-null  int64
#  5   Birth rate, crude (per 1,000 people)                          11440 non-null  float64
#  6   Death rate, crude (per 1,000 people)                          11416 non-null  float64
# ...

# %%
df.describe()
# Out:
#               Year  Birth rate, crude (per 1,000 people)  \
# count  12449.00000                          11440.000000
# mean    1989.00000                             28.643276
# std       17.03007                             13.131893
# min     1960.00000                              6.900000
# 25%     1974.00000                             16.600000
# 50%     1989.00000                             27.545500
# 75%     2004.00000                             40.881250
# max     2018.00000                             58.227000
#
#        Death rate, crude (per 1,000 people)  \
# count                          11416.000000
# mean                              10.588539
# std                                5.489382
# min                                1.127000
# 25%                                6.863750
# 50%                                9.200000
# 75%                               12.687000
# max                               54.444000
#
# ...

# %% [markdown]
# ## **To check the duplicate**

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## **To check th null  values**

# %%
df.isnull().sum()
# Out:
# Country Name                                                       0
# Country Code                                                       0
# Region                                                             0
# IncomeGroup                                                        0
# Year                                                               0
# Birth rate, crude (per 1,000 people)                            1009
# Death rate, crude (per 1,000 people)                            1033
# Electric power consumption (kWh per capita)                     6601
# GDP (USD)                                                       2871
# GDP per capita (USD)                                            2874
# Individuals using the Internet (% of population)                7385
# Infant mortality rate (per 1,000 live births)                   2465
# Life expectancy at birth (years)                                1273
# Population density (people per sq. km of land area)              604
# ...

# %%
df.isnull()
# Out:
#        Country Name  Country Code  Region  IncomeGroup   Year  \
# 0             False         False   False        False  False
# 1             False         False   False        False  False
# 2             False         False   False        False  False
# 3             False         False   False        False  False
# 4             False         False   False        False  False
# ...             ...           ...     ...          ...    ...
# 12444         False         False   False        False  False
# 12445         False         False   False        False  False
# 12446         False         False   False        False  False
# 12447         False         False   False        False  False
# 12448         False         False   False        False  False
#
#        Birth rate, crude (per 1,000 people)  \
# 0                                      True
# 1                                     False
# 2                                     False
# ...

# %%
df.isnull().sum()/len(df)*100
# Out:
# Country Name                                                     0.000000
# Country Code                                                     0.000000
# Region                                                           0.000000
# IncomeGroup                                                      0.000000
# Year                                                             0.000000
# Birth rate, crude (per 1,000 people)                             8.105069
# Death rate, crude (per 1,000 people)                             8.297855
# Electric power consumption (kWh per capita)                     53.024339
# GDP (USD)                                                       23.062093
# GDP per capita (USD)                                            23.086192
# Individuals using the Internet (% of population)                59.322034
# Infant mortality rate (per 1,000 live births)                   19.800787
# Life expectancy at birth (years)                                10.225721
# ...

# %%
null_percentages = df.isnull().mean() * 100
cols_to_drop = null_percentages[null_percentages > 30].index
df = df.drop(cols_to_drop, axis=1)

# %%
df.isnull().sum()/len(df)*100
# Out:
# Country Name                                            0.000000
# Country Code                                            0.000000
# Region                                                  0.000000
# IncomeGroup                                             0.000000
# Year                                                    0.000000
# Birth rate, crude (per 1,000 people)                    8.105069
# Death rate, crude (per 1,000 people)                    8.297855
# GDP (USD)                                              23.062093
# GDP per capita (USD)                                   23.086192
# Infant mortality rate (per 1,000 live births)          19.800787
# Life expectancy at birth (years)                       10.225721
# Population density (people per sq. km of land area)     4.851795
# dtype: float64

# %%
for col in ['Country Name', 'Country Code', 'Region', 'IncomeGroup']:
    df[col] = df[col].fillna(df[col].mode().iloc[0])

# %%
for col in ['Birth rate, crude (per 1,000 people)', 'Death rate, crude (per 1,000 people)', 'GDP (USD)', 'GDP per capita (USD)', 'Infant mortality rate (per 1,000 live births)', 'Life expectancy at birth (years)', 'Population density (people per sq. km of land area)']:
    df[col] = df[col].fillna(df[col].median())

# %%
df.isnull().sum()/len(df)*100
# Out:
# Country Name                                           0.0
# Country Code                                           0.0
# Region                                                 0.0
# IncomeGroup                                            0.0
# Year                                                   0.0
# Birth rate, crude (per 1,000 people)                   0.0
# Death rate, crude (per 1,000 people)                   0.0
# GDP (USD)                                              0.0
# GDP per capita (USD)                                   0.0
# Infant mortality rate (per 1,000 live births)          0.0
# Life expectancy at birth (years)                       0.0
# Population density (people per sq. km of land area)    0.0
# dtype: float64

# %%
df.isnull().sum()
# Out:
# Country Name                                           0
# Country Code                                           0
# Region                                                 0
# IncomeGroup                                            0
# Year                                                   0
# Birth rate, crude (per 1,000 people)                   0
# Death rate, crude (per 1,000 people)                   0
# GDP (USD)                                              0
# GDP per capita (USD)                                   0
# Infant mortality rate (per 1,000 live births)          0
# Life expectancy at birth (years)                       0
# Population density (people per sq. km of land area)    0
# dtype: int64

# %%
filtered_df = df[(df['Birth rate, crude (per 1,000 people)'] > 20) & (df['GDP per capita (USD)'] < 10000)]
filtered_df
# Out:
#       Country Name Country Code              Region IncomeGroup  Year  \
# 0      Afghanistan          AFG          South Asia  Low income  2018
# 1      Afghanistan          AFG          South Asia  Low income  2017
# 2      Afghanistan          AFG          South Asia  Low income  2016
# 3      Afghanistan          AFG          South Asia  Low income  2015
# 4      Afghanistan          AFG          South Asia  Low income  2014
# ...            ...          ...                 ...         ...   ...
# 12444     Zimbabwe          ZWE  Sub-Saharan Africa  Low income  1964
# 12445     Zimbabwe          ZWE  Sub-Saharan Africa  Low income  1963
# 12446     Zimbabwe          ZWE  Sub-Saharan Africa  Low income  1962
# 12447     Zimbabwe          ZWE  Sub-Saharan Africa  Low income  1961
# 12448     Zimbabwe          ZWE  Sub-Saharan Africa  Low income  1960
#
#        Birth rate, crude (per 1,000 people)  \
# 0                                   27.5455
# ...

# %%
filtered_df = df[(df['Region'] == 'Europe & Central Asia') & (df['IncomeGroup'] == 'High income')]
filtered_df
# Out:
# Empty DataFrame
# Columns: [Country Name, Country Code, Region, IncomeGroup, Year, Birth rate, crude (per 1,000 people), Death rate, crude (per 1,000 people), GDP (USD), GDP per capita (USD), Infant mortality rate (per 1,000 live births), Life expectancy at birth (years), Population density (people per sq. km of land area)]
# Index: []

# %%
filtered_df = df[df['Year'].isin([2020, 2021])]
filtered_df
# Out:
# Empty DataFrame
# Columns: [Country Name, Country Code, Region, IncomeGroup, Year, Birth rate, crude (per 1,000 people), Death rate, crude (per 1,000 people), GDP (USD), GDP per capita (USD), Infant mortality rate (per 1,000 live births), Life expectancy at birth (years), Population density (people per sq. km of land area)]
# Index: []

# %%
filtered_df = df[(df['Life expectancy at birth (years)'] >= 70) & (df['Life expectancy at birth (years)'] <= 80)]
filtered_df
# Out:
#              Country Name Country Code                      Region  \
# 60                Albania          ALB       Europe & Central Asia
# 61                Albania          ALB       Europe & Central Asia
# 62                Albania          ALB       Europe & Central Asia
# 63                Albania          ALB       Europe & Central Asia
# 64                Albania          ALB       Europe & Central Asia
# ...                   ...          ...                         ...
# 12231  West Bank and Gaza          PSE  Middle East & North Africa
# 12232  West Bank and Gaza          PSE  Middle East & North Africa
# 12233  West Bank and Gaza          PSE  Middle East & North Africa
# 12234  West Bank and Gaza          PSE  Middle East & North Africa
# 12235  West Bank and Gaza          PSE  Middle East & North Africa
#
#                IncomeGroup  Year  Birth rate, crude (per 1,000 people)  \
# 60     Upper middle income  2017                                11.934
# ...

# %%
filtered_df = df[(df['Birth rate, crude (per 1,000 people)'] > 20) & (df['GDP per capita (USD)'] < 10000) & (df['Year'].isin([2020, 2021]))]
filtered_df
# Out:
# Empty DataFrame
# Columns: [Country Name, Country Code, Region, IncomeGroup, Year, Birth rate, crude (per 1,000 people), Death rate, crude (per 1,000 people), GDP (USD), GDP per capita (USD), Infant mortality rate (per 1,000 live births), Life expectancy at birth (years), Population density (people per sq. km of land area)]
# Index: []

# %%
df.columns
# Out:
# Index(['Country Name', 'Country Code', 'Region', 'IncomeGroup', 'Year',
#        'Birth rate, crude (per 1,000 people)',
#        'Death rate, crude (per 1,000 people)', 'GDP (USD)',
#        'GDP per capita (USD)', 'Infant mortality rate (per 1,000 live births)',
#        'Life expectancy at birth (years)',
#        'Population density (people per sq. km of land area)'],
#       dtype='object')

# %%
europe_central_asia = df[df['Region'] == 'Europe & Central Asia']
europe_central_asia
# Out:
#       Country Name Country Code                 Region          IncomeGroup  \
# 59         Albania          ALB  Europe & Central Asia  Upper middle income
# 60         Albania          ALB  Europe & Central Asia  Upper middle income
# 61         Albania          ALB  Europe & Central Asia  Upper middle income
# 62         Albania          ALB  Europe & Central Asia  Upper middle income
# 63         Albania          ALB  Europe & Central Asia  Upper middle income
# ...            ...          ...                    ...                  ...
# 11972   Uzbekistan          UZB  Europe & Central Asia  Lower middle income
# 11973   Uzbekistan          UZB  Europe & Central Asia  Lower middle income
# 11974   Uzbekistan          UZB  Europe & Central Asia  Lower middle income
# 11975   Uzbekistan          UZB  Europe & Central Asia  Lower middle income
# 11976   Uzbekistan          UZB  Europe & Central Asia  Lower middle income
#
#        Year  Birth rate, crude (per 1,000 people)  \
# ...

# %%
birth_rate_by_income = df.groupby('IncomeGroup')['Birth rate, crude (per 1,000 people)'].agg(['mean', 'count'])
birth_rate_by_income
# Out:
#                            mean  count
# IncomeGroup
# High income: OECD     14.755739   1888
# High income: nonOECD  22.376482   2773
# Low income            43.271619   1829
# Lower middle income   34.942335   2832
# Upper middle income   27.970319   3127

# %%
mean_gdp_per_capita = df['GDP per capita (USD)'].mean()
print(mean_gdp_per_capita)
median_gdp_per_capita = df['GDP per capita (USD)'].median()
print(median_gdp_per_capita)
std_gdp_per_capita = df['GDP per capita (USD)'].std()
print(std_gdp_per_capita)
# Out:
# 6759.143571274802
# 1852.81
# 14436.581441730588

# %%
import matplotlib.pyplot as plt
df.boxplot(column='GDP per capita (USD)')
plt.show()

# %%
df['GDP per capita (USD)'].hist()
plt.show()

# %%
skewness = df['GDP per capita (USD)'].skew()
print(skewness)
kurtosis = df['GDP per capita (USD)'].kurt()
print(kurtosis)
# Out:
# 4.83691023103948
# 34.05276336902143

# %%
from scipy.stats import ttest_ind
high_income = df[df['IncomeGroup'] == 'High income']
print(high_income)
low_income = df[df['IncomeGroup'] == 'Low income']
print(low_income)
t_stat, p_value = ttest_ind(high_income['GDP per capita (USD)'], low_income['GDP per capita (USD)'])
print(t_stat, p_value)
# Out:
# Empty DataFrame
# Columns: [Country Name, Country Code, Region, IncomeGroup, Year, Birth rate, crude (per 1,000 people), Death rate, crude (per 1,000 people), GDP (USD), GDP per capita (USD), Infant mortality rate (per 1,000 live births), Life expectancy at birth (years), Population density (people per sq. km of land area)]
# Index: []
#       Country Name Country Code              Region IncomeGroup  Year  \
# 0      Afghanistan          AFG          South Asia  Low income  2018
# 1      Afghanistan          AFG          South Asia  Low income  2017
# 2      Afghanistan          AFG          South Asia  Low income  2016
# 3      Afghanistan          AFG          South Asia  Low income  2015
# 4      Afghanistan          AFG          South Asia  Low income  2014
# ...            ...          ...                 ...         ...   ...
# 12444     Zimbabwe          ZWE  Sub-Saharan Africa  Low income  1964
# 12445     Zimbabwe          ZWE  Sub-Saharan Africa  Low income  1963
# ...
