# %% [markdown]
# + ## **Impotr Libraries**

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %% [markdown]
# + ## **Load Data**

# %%
dataset= pd.read_csv('retail_data.csv')
dataset
# Out:
#         Transaction_ID  Customer_ID                 Name  \
# 0            8691788.0      37249.0  Michelle Harrington
# 1            2174773.0      69749.0          Kelsey Hill
# 2            6679610.0      30192.0         Scott Jensen
# 3            7232460.0      62101.0        Joseph Miller
# 4            4983775.0      27901.0        Debra Coleman
# ...                ...          ...                  ...
# 302005       4246475.0      12104.0         Meagan Ellis
# 302006       1197603.0      69772.0          Mathew Beck
# 302007       7743242.0      28449.0           Daniel Lee
# 302008       9301950.0      45477.0       Patrick Wilson
# 302009       2882826.0      53626.0       Dustin Merritt
#
#                            Email         Phone                       Address  \
# 0              Ebony39@gmail.com  1.414787e+09             3959 Amanda Burgs
# 1               Mark36@gmail.com  6.852900e+09            82072 Dawn Centers
# ...

# %% [markdown]
# + ## **Examine Data**

# %%
dataset.describe()
# Out:
#        Transaction_ID    Customer_ID         Phone        Zipcode  \
# count    3.016770e+05  301702.000000  3.016480e+05  301670.000000
# mean     5.495823e+06   55006.553934  5.501464e+09   50298.951019
# std      2.595565e+06   26005.675200  2.596017e+09   28972.807134
# min      1.000007e+06   10000.000000  1.000049e+09     501.000000
# 25%      3.247930e+06   32469.250000  3.255061e+09   25425.000000
# 50%      5.499657e+06   55012.000000  5.505812e+09   50602.500000
# 75%      7.739509e+06   77511.000000  7.749860e+09   75252.000000
# max      9.999995e+06   99999.000000  9.999996e+09   99949.000000
#
#                  Age           Year  Total_Purchases         Amount  \
# count  301837.000000  301660.000000    301649.000000  301653.000000
# mean       35.481326    2023.165113         5.359729     255.163659
# std        15.021933       0.371283         2.868575     141.389640
# min        18.000000    2023.000000         1.000000      10.000219
# ...

# %%
dataset.head(2)
# Out:
#    Transaction_ID  Customer_ID                 Name              Email  \
# 0       8691788.0      37249.0  Michelle Harrington  Ebony39@gmail.com
# 1       2174773.0      69749.0          Kelsey Hill   Mark36@gmail.com
#
#           Phone             Address        City    State  Zipcode  Country  \
# 0  1.414787e+09   3959 Amanda Burgs    Dortmund   Berlin  77985.0  Germany
# 1  6.852900e+09  82072 Dawn Centers  Nottingham  England  99071.0       UK
#
#    ...  Total_Amount Product_Category Product_Brand Product_Type   Feedback  \
# 0  ...    324.086270         Clothing          Nike       Shorts  Excellent
# 1  ...    806.707815      Electronics       Samsung       Tablet  Excellent
#
#    Shipping_Method Payment_Method Order_Status  Ratings        products
# 0         Same-Day     Debit Card      Shipped      5.0  Cycling shorts
# 1         Standard    Credit Card   Processing      4.0      Lenovo Tab
#
# [2 rows x 30 columns]

# %% [markdown]
# + ## **Check Overall Data**

# %%
dataset.shape
# Out:
# (302010, 30)

# %% [markdown]
# + ## **Check DataType**

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 302010 entries, 0 to 302009
# Data columns (total 30 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Transaction_ID    301677 non-null  float64
#  1   Customer_ID       301702 non-null  float64
#  2   Name              301628 non-null  object
#  3   Email             301663 non-null  object
#  4   Phone             301648 non-null  float64
#  5   Address           301695 non-null  object
#  6   City              301762 non-null  object
#  7   State             301729 non-null  object
#  8   Zipcode           301670 non-null  float64
#  9   Country           301739 non-null  object
#  10  Age               301837 non-null  float64
#  11  Gender            301693 non-null  object
#  12  Income            301720 non-null  object
#  13  Customer_Segment  301795 non-null  object
#  14  Date              301651 non-null  object
# ...

# %% [markdown]
# + ## **Check Missing Values**

# %%
dataset.isnull()
# Out:
#         Transaction_ID  Customer_ID   Name  Email  Phone  Address   City  \
# 0                False        False  False  False  False    False  False
# 1                False        False  False  False  False    False  False
# 2                False        False  False  False  False    False  False
# 3                False        False  False  False  False    False  False
# 4                False        False  False  False  False    False  False
# ...                ...          ...    ...    ...    ...      ...    ...
# 302005           False        False  False  False  False    False  False
# 302006           False        False  False  False  False    False  False
# 302007           False        False  False  False  False    False  False
# 302008           False        False  False  False  False    False  False
# 302009           False        False  False  False  False    False  False
#
#         State  Zipcode  Country  ...  Total_Amount  Product_Category  \
# ...

# %%
dataset.isnull().sum()
# Out:
# Transaction_ID      333
# Customer_ID         308
# Name                382
# Email               347
# Phone               362
# Address             315
# City                248
# State               281
# Zipcode             340
# Country             271
# Age                 173
# Gender              317
# Income              290
# Customer_Segment    215
# Date                359
# Year                350
# Month               273
# Time                350
# Total_Purchases     361
# Amount              357
# Total_Amount        350
# Product_Category    283
# Product_Brand       281
# Product_Type          0
# Feedback            184
# Shipping_Method     337
# Payment_Method      297
# Order_Status        235
# Ratings             184
# products              0
# dtype: int64

# %%
dataset.shape[0]
# Out:
# 302010

# %%
(dataset.isnull().sum()/dataset.shape[0])*100      # Check Missing values in %
# Out:
# Transaction_ID      0.110261
# Customer_ID         0.101983
# Name                0.126486
# Email               0.114897
# Phone               0.119864
# Address             0.104301
# City                0.082116
# State               0.093043
# Zipcode             0.112579
# Country             0.089732
# Age                 0.057283
# Gender              0.104963
# Income              0.096023
# Customer_Segment    0.071190
# Date                0.118870
# Year                0.115890
# Month               0.090394
# Time                0.115890
# Total_Purchases     0.119532
# Amount              0.118208
# Total_Amount        0.115890
# Product_Category    0.093706
# Product_Brand       0.093043
# Product_Type        0.000000
# Feedback            0.060925
# Shipping_Method     0.111586
# Payment_Method      0.098341
# Order_Status        0.077812
# Ratings             0.060925
# products            0.000000
# dtype: float64

# %% [markdown]
# + ## **Remove Missing Data**

# %%
dataset.dropna(inplace=True)

# %%
dataset.isnull().sum()
# Out:
# Transaction_ID      0
# Customer_ID         0
# Name                0
# Email               0
# Phone               0
# Address             0
# City                0
# State               0
# Zipcode             0
# Country             0
# Age                 0
# Gender              0
# Income              0
# Customer_Segment    0
# Date                0
# Year                0
# Month               0
# Time                0
# Total_Purchases     0
# Amount              0
# Total_Amount        0
# Product_Category    0
# Product_Brand       0
# Product_Type        0
# Feedback            0
# Shipping_Method     0
# Payment_Method      0
# Order_Status        0
# Ratings             0
# products            0
# dtype: int64

# %%
dataset.duplicated().sum()
# Out:
# 3

# %% [markdown]
# ## **Cleaning Data**

# %% [markdown]
# + ### **Name**

# %%
# x= dataset['Name'][0]
# x[:x.index(" ")]

# %%
def Firstname(x):
    return x[:x.index(" ")]
dataset["First_name"]= dataset["Name"].apply(Firstname)
dataset.head(3)
# Out:
#    Transaction_ID  Customer_ID                 Name              Email  \
# 0       8691788.0      37249.0  Michelle Harrington  Ebony39@gmail.com
# 1       2174773.0      69749.0          Kelsey Hill   Mark36@gmail.com
# 2       6679610.0      30192.0         Scott Jensen  Shane85@gmail.com
#
#           Phone             Address        City            State  Zipcode  \
# 0  1.414787e+09   3959 Amanda Burgs    Dortmund           Berlin  77985.0
# 1  6.852900e+09  82072 Dawn Centers  Nottingham          England  99071.0
# 2  8.362160e+09   4133 Young Canyon     Geelong  New South Wales  75929.0
#
#      Country  ...  Product_Category  Product_Brand Product_Type   Feedback  \
# 0    Germany  ...          Clothing           Nike       Shorts  Excellent
# 1         UK  ...       Electronics        Samsung       Tablet  Excellent
# 2  Australia  ...             Books  Penguin Books   Children's    Average
#
#   Shipping_Method  Payment_Method Order_Status Ratings          products  \
# ...

# %%
def Lastname(x):
    return x[x.index(" ")+1:]
dataset["Last_name"]= dataset["Name"].apply(Lastname)
dataset.head(3)
# Out:
#    Transaction_ID  Customer_ID                 Name              Email  \
# 0       8691788.0      37249.0  Michelle Harrington  Ebony39@gmail.com
# 1       2174773.0      69749.0          Kelsey Hill   Mark36@gmail.com
# 2       6679610.0      30192.0         Scott Jensen  Shane85@gmail.com
#
#           Phone             Address        City            State  Zipcode  \
# 0  1.414787e+09   3959 Amanda Burgs    Dortmund           Berlin  77985.0
# 1  6.852900e+09  82072 Dawn Centers  Nottingham          England  99071.0
# 2  8.362160e+09   4133 Young Canyon     Geelong  New South Wales  75929.0
#
#      Country  ...  Product_Brand Product_Type   Feedback Shipping_Method  \
# 0    Germany  ...           Nike       Shorts  Excellent        Same-Day
# 1         UK  ...        Samsung       Tablet  Excellent        Standard
# 2  Australia  ...  Penguin Books   Children's    Average        Same-Day
#
#   Payment_Method  Order_Status Ratings          products  First_name  \
# ...

# %% [markdown]
# + ### **Date**

# %%
dataset["Date"]
# Out:
# 0          9/18/2023
# 1         12/31/2023
# 2          4/26/2023
# 3           05-08-23
# 4           01-10-24
#              ...
# 302005     1/20/2024
# 302006    12/28/2023
# 302007     2/27/2024
# 302008      09-03-23
# 302009      01-08-24
# Name: Date, Length: 293911, dtype: object

# %%
dataset['Date'] = pd.to_datetime(dataset['Date'], format='mixed')
dataset['Date']
# Out:
# 0        2023-09-18
# 1        2023-12-31
# 2        2023-04-26
# 3        2023-05-08
# 4        2024-01-10
#             ...
# 302005   2024-01-20
# 302006   2023-12-28
# 302007   2024-02-27
# 302008   2023-09-03
# 302009   2024-01-08
# Name: Date, Length: 293911, dtype: datetime64[ns]

# %%
dataset.head(3)
# Out:
#    Transaction_ID  Customer_ID                 Name              Email  \
# 0       8691788.0      37249.0  Michelle Harrington  Ebony39@gmail.com
# 1       2174773.0      69749.0          Kelsey Hill   Mark36@gmail.com
# 2       6679610.0      30192.0         Scott Jensen  Shane85@gmail.com
#
#           Phone             Address        City            State  Zipcode  \
# 0  1.414787e+09   3959 Amanda Burgs    Dortmund           Berlin  77985.0
# 1  6.852900e+09  82072 Dawn Centers  Nottingham          England  99071.0
# 2  8.362160e+09   4133 Young Canyon     Geelong  New South Wales  75929.0
#
#      Country  ...  Product_Brand Product_Type   Feedback Shipping_Method  \
# 0    Germany  ...           Nike       Shorts  Excellent        Same-Day
# 1         UK  ...        Samsung       Tablet  Excellent        Standard
# 2  Australia  ...  Penguin Books   Children's    Average        Same-Day
#
#   Payment_Method  Order_Status Ratings          products  First_name  \
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 293911 entries, 0 to 302009
# Data columns (total 32 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Transaction_ID    293911 non-null  float64
#  1   Customer_ID       293911 non-null  float64
#  2   Name              293911 non-null  object
#  3   Email             293911 non-null  object
#  4   Phone             293911 non-null  float64
#  5   Address           293911 non-null  object
#  6   City              293911 non-null  object
#  7   State             293911 non-null  object
#  8   Zipcode           293911 non-null  float64
#  9   Country           293911 non-null  object
#  10  Age               293911 non-null  float64
#  11  Gender            293911 non-null  object
#  12  Income            293911 non-null  object
#  13  Customer_Segment  293911 non-null  object
#  14  Date              293911 non-null  datetime64[ns]
# ...

# %% [markdown]
# + ### **Phone**

# %%
dataset['Phone']
# Out:
# 0         1.414787e+09
# 1         6.852900e+09
# 2         8.362160e+09
# 3         2.776752e+09
# 4         9.098268e+09
#               ...
# 302005    7.466354e+09
# 302006    5.754305e+09
# 302007    9.382530e+09
# 302008    9.373222e+09
# 302009    9.518927e+09
# Name: Phone, Length: 293911, dtype: float64

# %%
dataset['Phone']= dataset['Phone'][0:].astype('Int64')
dataset['Phone']
# Out:
# 0         1414786801
# 1         6852899987
# 2         8362160449
# 3         2776751724
# 4         9098267635
#              ...
# 302005    7466353743
# 302006    5754304957
# 302007    9382530370
# 302008    9373222023
# 302009    9518926645
# Name: Phone, Length: 293911, dtype: Int64

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 293911 entries, 0 to 302009
# Data columns (total 32 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Transaction_ID    293911 non-null  float64
#  1   Customer_ID       293911 non-null  float64
#  2   Name              293911 non-null  object
#  3   Email             293911 non-null  object
#  4   Phone             293911 non-null  Int64
#  5   Address           293911 non-null  object
#  6   City              293911 non-null  object
#  7   State             293911 non-null  object
#  8   Zipcode           293911 non-null  float64
#  9   Country           293911 non-null  object
#  10  Age               293911 non-null  float64
#  11  Gender            293911 non-null  object
#  12  Income            293911 non-null  object
#  13  Customer_Segment  293911 non-null  object
#  14  Date              293911 non-null  datetime64[ns]
# ...

# %%
dataset.head(3)
# Out:
#    Transaction_ID  Customer_ID                 Name              Email  \
# 0       8691788.0      37249.0  Michelle Harrington  Ebony39@gmail.com
# 1       2174773.0      69749.0          Kelsey Hill   Mark36@gmail.com
# 2       6679610.0      30192.0         Scott Jensen  Shane85@gmail.com
#
#         Phone             Address        City            State  Zipcode  \
# 0  1414786801   3959 Amanda Burgs    Dortmund           Berlin  77985.0
# 1  6852899987  82072 Dawn Centers  Nottingham          England  99071.0
# 2  8362160449   4133 Young Canyon     Geelong  New South Wales  75929.0
#
#      Country  ...  Product_Brand Product_Type   Feedback Shipping_Method  \
# 0    Germany  ...           Nike       Shorts  Excellent        Same-Day
# 1         UK  ...        Samsung       Tablet  Excellent        Standard
# 2  Australia  ...  Penguin Books   Children's    Average        Same-Day
#
#   Payment_Method  Order_Status Ratings          products  First_name  \
# ...

# %%
dataset.drop(columns=['Name'],inplace=True)
dataset.drop(columns=['Month'],inplace=True)

# %%
dataset.head(3)
# Out:
#    Transaction_ID  Customer_ID              Email       Phone  \
# 0       8691788.0      37249.0  Ebony39@gmail.com  1414786801
# 1       2174773.0      69749.0   Mark36@gmail.com  6852899987
# 2       6679610.0      30192.0  Shane85@gmail.com  8362160449
#
#               Address        City            State  Zipcode    Country   Age  \
# 0   3959 Amanda Burgs    Dortmund           Berlin  77985.0    Germany  21.0
# 1  82072 Dawn Centers  Nottingham          England  99071.0         UK  19.0
# 2   4133 Young Canyon     Geelong  New South Wales  75929.0  Australia  48.0
#
#    ...  Product_Brand Product_Type   Feedback Shipping_Method  Payment_Method  \
# 0  ...           Nike       Shorts  Excellent        Same-Day      Debit Card
# 1  ...        Samsung       Tablet  Excellent        Standard     Credit Card
# 2  ...  Penguin Books   Children's    Average        Same-Day     Credit Card
#
#   Order_Status  Ratings          products  First_name   Last_name
# ...

# %%
order_of_column= list(dataset.columns)
order_of_column
# Out:
# ['Transaction_ID',
#  'Customer_ID',
#  'Email',
#  'Phone',
#  'Address',
#  'City',
#  'State',
#  'Zipcode',
#  'Country',
#  'Age',
#  'Gender',
#  'Income',
#  'Customer_Segment',
#  'Date',
#  'Year',
#  'Time',
#  'Total_Purchases',
#  'Amount',
#  'Total_Amount',
#  'Product_Category',
#  'Product_Brand',
#  'Product_Type',
#  'Feedback',
#  'Shipping_Method',
#  'Payment_Method',
#  'Order_Status',
#  'Ratings',
#  'products',
#  'First_name',
#  'Last_name']

# %%
dataset= dataset[['First_name',
 'Last_name','Transaction_ID',
 'Customer_ID',
 'Email',
 'Phone',
 'Address',
 'City',
 'State',
 'Zipcode',
 'Country',
 'Age',
 'Gender',
 'Income',
 'Customer_Segment',
 'Date',
 'Year',
 'Time',
 'Total_Purchases',
 'Amount',
 'Total_Amount',
 'Product_Category',
 'Product_Brand',
 'Product_Type',
 'Feedback',
 'Shipping_Method',
 'Payment_Method',
 'Order_Status',
 'Ratings',
 'products']]
dataset.head(3)
# Out:
#   First_name   Last_name  Transaction_ID  Customer_ID              Email  \
# 0   Michelle  Harrington       8691788.0      37249.0  Ebony39@gmail.com
# 1     Kelsey        Hill       2174773.0      69749.0   Mark36@gmail.com
# 2      Scott      Jensen       6679610.0      30192.0  Shane85@gmail.com
#
#         Phone             Address        City            State  Zipcode  ...  \
# 0  1414786801   3959 Amanda Burgs    Dortmund           Berlin  77985.0  ...
# 1  6852899987  82072 Dawn Centers  Nottingham          England  99071.0  ...
# 2  8362160449   4133 Young Canyon     Geelong  New South Wales  75929.0  ...
#
#   Total_Amount  Product_Category  Product_Brand Product_Type   Feedback  \
# 0   324.086270          Clothing           Nike       Shorts  Excellent
# 1   806.707815       Electronics        Samsung       Tablet  Excellent
# 2  1063.432799             Books  Penguin Books   Children's    Average
#
# ...

# %%
dataset.tail(3)
# Out:
#        First_name Last_name  Transaction_ID  Customer_ID  \
# 302007     Daniel       Lee       7743242.0      28449.0
# 302008    Patrick    Wilson       9301950.0      45477.0
# 302009     Dustin   Merritt       2882826.0      53626.0
#
#                            Email       Phone                       Address  \
# 302007  Christopher100@gmail.com  9382530370  407 Aaron Crossing Suite 495
# 302008       Rebecca65@gmail.com  9373222023               3204 Baird Port
# 302009       William14@gmail.com  9518926645           143 Amanda Crescent
#
#             City          State  Zipcode  ... Total_Amount  Product_Category  \
# 302007  Brighton        England  88038.0  ...   182.105285          Clothing
# 302008   Halifax        Ontario  67608.0  ...   120.834784        Home Decor
# 302009    Tucson  West Virginia  25242.0  ...  2382.233417        Home Decor
#
#        Product_Brand Product_Type Feedback Shipping_Method  Payment_Method  \
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 293911 entries, 0 to 302009
# Data columns (total 30 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   First_name        293911 non-null  object
#  1   Last_name         293911 non-null  object
#  2   Transaction_ID    293911 non-null  float64
#  3   Customer_ID       293911 non-null  float64
#  4   Email             293911 non-null  object
#  5   Phone             293911 non-null  Int64
#  6   Address           293911 non-null  object
#  7   City              293911 non-null  object
#  8   State             293911 non-null  object
#  9   Zipcode           293911 non-null  float64
#  10  Country           293911 non-null  object
#  11  Age               293911 non-null  float64
#  12  Gender            293911 non-null  object
#  13  Income            293911 non-null  object
#  14  Customer_Segment  293911 non-null  object
# ...

# %%
dataset['Time']
# Out:
# 0         22:03:55
# 1          8:42:04
# 2          4:06:29
# 3         14:55:17
# 4         16:54:07
#             ...
# 302005    23:40:29
# 302006     2:55:45
# 302007     2:43:49
# 302008    11:20:31
# 302009    11:44:36
# Name: Time, Length: 293911, dtype: object

# %%
dataset['Time']= pd.to_datetime(dataset['Time'], format='mixed')
dataset['Time']
# Out:
# 0        2024-07-10 22:03:55
# 1        2024-07-10 08:42:04
# 2        2024-07-10 04:06:29
# 3        2024-07-10 14:55:17
# 4        2024-07-10 16:54:07
#                  ...
# 302005   2024-07-10 23:40:29
# 302006   2024-07-10 02:55:45
# 302007   2024-07-10 02:43:49
# 302008   2024-07-10 11:20:31
# 302009   2024-07-10 11:44:36
# Name: Time, Length: 293911, dtype: datetime64[ns]

# %%
dataset['Time'].dt.time
# Out:
# 0         22:03:55
# 1         08:42:04
# 2         04:06:29
# 3         14:55:17
# 4         16:54:07
#             ...
# 302005    23:40:29
# 302006    02:55:45
# 302007    02:43:49
# 302008    11:20:31
# 302009    11:44:36
# Name: Time, Length: 293911, dtype: object

# %%
dataset['Time']
# Out:
# 0        2024-07-10 22:03:55
# 1        2024-07-10 08:42:04
# 2        2024-07-10 04:06:29
# 3        2024-07-10 14:55:17
# 4        2024-07-10 16:54:07
#                  ...
# 302005   2024-07-10 23:40:29
# 302006   2024-07-10 02:55:45
# 302007   2024-07-10 02:43:49
# 302008   2024-07-10 11:20:31
# 302009   2024-07-10 11:44:36
# Name: Time, Length: 293911, dtype: datetime64[ns]

# %%
dataset['Time'] = pd.to_datetime(dataset['Time']).dt.strftime('%H:%M:%S')
dataset['Time']
# Out:
# 0         22:03:55
# 1         08:42:04
# 2         04:06:29
# 3         14:55:17
# 4         16:54:07
#             ...
# 302005    23:40:29
# 302006    02:55:45
# 302007    02:43:49
# 302008    11:20:31
# 302009    11:44:36
# Name: Time, Length: 293911, dtype: object

# %% [markdown]
# ## **Exploratory data analysis (EDA)**

# %%
dataset.describe().T
# Out:
#                     count                           mean                  min  \
# Transaction_ID   293911.0                 5493725.586058            1000007.0
# Customer_ID      293911.0                   55013.400523              10000.0
# Phone            293911.0              5500607077.126644         1000049414.0
# Zipcode          293911.0                    50288.38383                501.0
# Age              293911.0                      35.465767                 18.0
# Date               293911  2023-08-30 16:41:37.637720320  2023-03-01 00:00:00
# Year             293911.0                    2023.165125               2023.0
# Total_Purchases  293911.0                       5.359864                  1.0
# Amount           293911.0                     255.153307            10.000219
# Total_Amount     293911.0                    1367.686983             10.00375
# Ratings          293911.0                       3.162301                  1.0
#
# ...

# %%
dataset.describe(include="object")
# Out:
#        First_name Last_name                Email  \
# count      293911    293911               293911
# unique        695      9288                52530
# top       Michael     Smith  Michael59@gmail.com
# freq         6470      6066                   92
#
#                                Address     City    State Country  Gender  \
# count                           293911   293911   293911  293911  293911
# unique                          291610      130       54       5       2
# top     29378 Benjamin Parks Suite 015  Chicago  England     USA    Male
# freq                                 2    21109    61398   92800  182764
#
#         Income Customer_Segment      Time Product_Category Product_Brand  \
# count   293911           293911    293911           293911        293911
# unique       3                3     83435                5            18
# top     Medium          Regular  02:16:01      Electronics         Pepsi
# ...

# %% [markdown]
# + ### **Histogram to understand the distribution**

# %%
import warnings
warnings.filterwarnings('ignore')
for i in dataset.select_dtypes(include="number").columns:
    sns.histplot(data=dataset,x=i)
    plt.show()

# %%
dataset.isnull().sum()
dataset.shape
# Out:
# (293911, 30)

# %%
dataset
# Out:
#        First_name   Last_name  Transaction_ID  Customer_ID  \
# 0        Michelle  Harrington       8691788.0      37249.0
# 1          Kelsey        Hill       2174773.0      69749.0
# 2           Scott      Jensen       6679610.0      30192.0
# 3          Joseph      Miller       7232460.0      62101.0
# 4           Debra     Coleman       4983775.0      27901.0
# ...           ...         ...             ...          ...
# 302005     Meagan       Ellis       4246475.0      12104.0
# 302006     Mathew        Beck       1197603.0      69772.0
# 302007     Daniel         Lee       7743242.0      28449.0
# 302008    Patrick      Wilson       9301950.0      45477.0
# 302009     Dustin     Merritt       2882826.0      53626.0
#
#                            Email       Phone                       Address  \
# 0              Ebony39@gmail.com  1414786801             3959 Amanda Burgs
# 1               Mark36@gmail.com  6852899987            82072 Dawn Centers
# ...

# %% [markdown]
# + ### **Shipping_Method**

# %%
dataset['Shipping_Method'].value_counts()
# Out:
# Shipping_Method
# Same-Day    101541
# Express      99600
# Standard     92770
# Name: count, dtype: int64

# %%
x= dataset['Shipping_Method'].value_counts().index
y= dataset['Shipping_Method'].value_counts().values
print(x)
print(y)
# Out:
# Index(['Same-Day', 'Express', 'Standard'], dtype='object', name='Shipping_Method')
# [101541  99600  92770]

# %%
plt.pie(y, labels=x, startangle=90, autopct="%0.2f%%")
plt.legend(loc=2)
plt.title('Shipping_Method')
plt.show()

# %%
sns.countplot(x="Shipping_Method", data=dataset, hue="Product_Category")
plt.show()

# %% [markdown]
# + ### **Product_Category**

# %%
sns.countplot(x="Product_Category", data=dataset)
plt.show()

# %%
sns.countplot(x="Product_Category", data=dataset[dataset['Product_Category']=="Clothing"], hue="Product_Type")
plt.show()

# %%
sns.countplot(x="Product_Category", data=dataset[dataset['Product_Category']=="Electronics"], hue="Product_Type")
plt.show()

# %%
sns.countplot(x="Product_Category", data=dataset[dataset['Product_Category']=="Books"], hue="Product_Type")
plt.legend(loc=2)
plt.show()

# %%
sns.countplot(x="Product_Category", data=dataset[dataset['Product_Category']=="Home Decor"], hue="Product_Type")
plt.show()

# %%
sns.countplot(x="Product_Category", data=dataset[dataset['Product_Category']=="Grocery"], hue="Product_Type")
plt.show()

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 293911 entries, 0 to 302009
# Data columns (total 30 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   First_name        293911 non-null  object
#  1   Last_name         293911 non-null  object
#  2   Transaction_ID    293911 non-null  float64
#  3   Customer_ID       293911 non-null  float64
#  4   Email             293911 non-null  object
#  5   Phone             293911 non-null  Int64
#  6   Address           293911 non-null  object
#  7   City              293911 non-null  object
#  8   State             293911 non-null  object
#  9   Zipcode           293911 non-null  float64
#  10  Country           293911 non-null  object
#  11  Age               293911 non-null  float64
#  12  Gender            293911 non-null  object
#  13  Income            293911 non-null  object
#  14  Customer_Segment  293911 non-null  object
# ...

# %%
dataset['Year']
# Out:
# 0         2023.0
# 1         2023.0
# 2         2023.0
# 3         2023.0
# 4         2024.0
#            ...
# 302005    2024.0
# 302006    2023.0
# 302007    2024.0
# 302008    2023.0
# 302009    2024.0
# Name: Year, Length: 293911, dtype: float64

# %%
dataset['Total_Purchases']
# Out:
# 0         3.0
# 1         2.0
# 2         3.0
# 3         7.0
# 4         2.0
#          ...
# 302005    5.0
# 302006    1.0
# 302007    3.0
# 302008    1.0
# 302009    7.0
# Name: Total_Purchases, Length: 293911, dtype: float64

# %%
dataset['Year'].value_counts()
# Out:
# Year
# 2023.0    245379
# 2024.0     48532
# Name: count, dtype: int64

# %%
plt.figure(figsize=(4,3))
sns.countplot(x="Year", data=dataset)
plt.show()

# %%
sns.barplot(x="Product_Category", y="Ratings", data=dataset, estimator='sum')
plt.show()

# %%
dataset['State'].value_counts()
# Out:
# State
# England            61398
# Berlin             51433
# New South Wales    44170
# Ontario            44110
# Connecticut        21120
# Maine              11953
# Georgia             9278
# Kansas              5375
# New Mexico          5077
# New York             970
# Maryland             955
# Pennsylvania         937
# California           926
# Nevada               921
# Ohio                 921
# Illinois             921
# Iowa                 920
# Minnesota            919
# Texas                919
# South Carolina       912
# Mississippi          912
# Hawaii               907
# Utah                 902
# Michigan             901
# West Virginia        899
# Louisiana            897
# New Jersey           894
# Alabama              889
# Virginia             888
# North Carolina       883
# Delaware             883
# Oregon               881
# Wyoming              880
# Rhode Island         879
# South Dakota         878
# Nebraska             877
# ...

# %% [markdown]
# + ### **Top 5 countries maximum sales**

# %%
dataset['State'].value_counts()[:5]
# Out:
# State
# England            61398
# Berlin             51433
# New South Wales    44170
# Ontario            44110
# Connecticut        21120
# Name: count, dtype: int64

# %% [markdown]
# + ### **Customer_Segment**

# %%
sns.countplot(x="Customer_Segment", data=dataset)
plt.show()

# %% [markdown]
# + ### **Feedback**

# %%
dataset['Feedback'].value_counts()
# Out:
# Feedback
# Excellent    98016
# Good         92696
# Average      61019
# Bad          42180
# Name: count, dtype: int64

# %%
plt.figure(figsize=(5,4))
sns.countplot(x="Feedback", data=dataset)
plt.title("Customer Feedback")
plt.savefig("Customer Feedback")
plt.show()

# %% [markdown]
# + ## **Incoding the Data**

# %%
from sklearn.preprocessing import LabelEncoder, StandardScaler

# %% [markdown]
# + ### **First_name**

# %%
First_name_en = LabelEncoder()
dataset['First_name']= First_name_en.fit_transform(dataset['First_name'])

# %% [markdown]
# + ### **Last_name**

# %%
Last_name_en = LabelEncoder()
dataset['Last_name']= Last_name_en.fit_transform(dataset['Last_name'])

# %% [markdown]
# + ### **Email**

# %%
Email_en = LabelEncoder()
dataset['Email']= Email_en.fit_transform(dataset['Email'])

# %% [markdown]
# + ### **Address**

# %%
Address_en = LabelEncoder()
dataset['Address']= Address_en.fit_transform(dataset['Address'])

# %% [markdown]
# + ### **City**

# %%
City_en = LabelEncoder()
dataset['City']= City_en.fit_transform(dataset['City'])

# %% [markdown]
# + ### **State**

# %%
State_en = LabelEncoder()
dataset['State']= State_en.fit_transform(dataset['State'])

# %% [markdown]
# + ### **Country**

# %%
Country_en = LabelEncoder()
dataset['Country']= Country_en.fit_transform(dataset['Country'])

# %% [markdown]
# + ### **Income**

# %%
Income_en = LabelEncoder()
dataset['Income']= Income_en.fit_transform(dataset['Income'])

# %% [markdown]
# + ###  **Gender**

# %%
Gender_en = LabelEncoder()
dataset['Gender']= Gender_en.fit_transform(dataset['Gender'])

# %% [markdown]
# + ### **Customer_Segment**

# %%
Customer_Segment_en = LabelEncoder()
dataset['Customer_Segment']= Customer_Segment_en.fit_transform(dataset['Customer_Segment'])

# %% [markdown]
# + ### **Product_Category**

# %%
Product_Category_en = LabelEncoder()
dataset['Product_Category']= Product_Category_en.fit_transform(dataset['Product_Category'])

# %% [markdown]
# + ### **Product_Brand**

# %%
Product_Brand_en = LabelEncoder()
dataset['Product_Brand']= Product_Brand_en.fit_transform(dataset['Product_Brand'])

# %% [markdown]
# + ### **Product_Type**

# %%
Product_Type_en = LabelEncoder()
dataset['Product_Type']= Product_Type_en.fit_transform(dataset['Product_Type'])

# %% [markdown]
# + ### **Feedback**

# %%
Feedback_en = LabelEncoder()
dataset['Feedback']= Feedback_en.fit_transform(dataset['Feedback'])

# %% [markdown]
# + ### **Shipping_Method**

# %%
Shipping_Method_en = LabelEncoder()
dataset['Shipping_Method']= Shipping_Method_en.fit_transform(dataset['Shipping_Method'])

# %% [markdown]
# + ### **Payment_Method**

# %%
Payment_Method_en = LabelEncoder()
dataset['Payment_Method']= Payment_Method_en.fit_transform(dataset['Payment_Method'])

# %% [markdown]
# + ### **Order_Status**

# %%
Order_Status_en = LabelEncoder()
dataset['Order_Status']= Order_Status_en.fit_transform(dataset['Order_Status'])

# %% [markdown]
# + ### **products**

# %%
products_en = LabelEncoder()
dataset['products']= products_en.fit_transform(dataset['products'])

# %% [markdown]
# + ### **Time**

# %%
products_en = LabelEncoder()
dataset['Time']= products_en.fit_transform(dataset['Time'])

# %%
dataset.head()
# Out:
#    First_name  Last_name  Transaction_ID  Customer_ID  Email       Phone  \
# 0         487       3340       8691788.0      37249.0  16389  1414786801
# 1         383       3491       2174773.0      69749.0  34896  6852899987
# 2         585       4106       6679610.0      30192.0  44610  8362160449
# 3         351       6310       7232460.0      62101.0  35231  2776751724
# 4         182       1797       4983775.0      27901.0   9522  9098267635
#
#    Address  City  State  Zipcode  ...  Total_Amount  Product_Category  \
# 0   115251    35      4  77985.0  ...    324.086270                 1
# 1   239182    87      9  99071.0  ...    806.707815                 2
# 2   120354    46     33  75929.0  ...   1063.432799                 0
# 3   237426    40     39  88420.0  ...   2466.854021                 4
# 4   169364    20      9  48704.0  ...    248.553049                 3
#
#    Product_Brand  Product_Type  Feedback Shipping_Method  Payment_Method  \
# ...

# %%
dataset['Time'] = pd.to_datetime(dataset['Time']).dt.strftime('%H:%M:%S')
dataset['Time']
# Out:
# 0         00:00:00
# 1         00:00:00
# 2         00:00:00
# 3         00:00:00
# 4         00:00:00
#             ...
# 302005    00:00:00
# 302006    00:00:00
# 302007    00:00:00
# 302008    00:00:00
# 302009    00:00:00
# Name: Time, Length: 293911, dtype: object

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 293911 entries, 0 to 302009
# Data columns (total 30 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   First_name        293911 non-null  int32
#  1   Last_name         293911 non-null  int32
#  2   Transaction_ID    293911 non-null  float64
#  3   Customer_ID       293911 non-null  float64
#  4   Email             293911 non-null  int32
#  5   Phone             293911 non-null  Int64
#  6   Address           293911 non-null  int32
#  7   City              293911 non-null  int32
#  8   State             293911 non-null  int32
#  9   Zipcode           293911 non-null  float64
#  10  Country           293911 non-null  int32
#  11  Age               293911 non-null  float64
#  12  Gender            293911 non-null  int32
#  13  Income            293911 non-null  int32
#  14  Customer_Segment  293911 non-null  int32
#  15  Date              293911 non-null  datetime64[ns]
# ...

# %%
dataset.shape
# Out:
# (293911, 30)

# %% [markdown]
# ## **Outlier Detection**

# %%
plt.figure(figsize=(4,3))
sns.boxplot(x="Transaction_ID", data=dataset)
plt.show()

# %%
plt.figure(figsize=(4,3))
sns.boxplot(x="Total_Amount", data=dataset)
plt.show()

# %% [markdown]
# # **Clustering algorithms (e.g., K-means)**

# %%
dataset.head(2)
# Out:
#    First_name  Last_name  Transaction_ID  Customer_ID  Email       Phone  \
# 0         487       3340       8691788.0      37249.0  16389  1414786801
# 1         383       3491       2174773.0      69749.0  34896  6852899987
#
#    Address  City  State  Zipcode  ...  Total_Amount  Product_Category  \
# 0   115251    35      4  77985.0  ...    324.086270                 1
# 1   239182    87      9  99071.0  ...    806.707815                 2
#
#    Product_Brand  Product_Type  Feedback Shipping_Method  Payment_Method  \
# 0             10            23         2               1               2
# 1             14            28         2               2               1
#
#   Order_Status  Ratings  products
# 0            3      5.0        86
# 1            2      4.0       164
#
# [2 rows x 30 columns]

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 293911 entries, 0 to 302009
# Data columns (total 30 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   First_name        293911 non-null  int32
#  1   Last_name         293911 non-null  int32
#  2   Transaction_ID    293911 non-null  float64
#  3   Customer_ID       293911 non-null  float64
#  4   Email             293911 non-null  int32
#  5   Phone             293911 non-null  Int64
#  6   Address           293911 non-null  int32
#  7   City              293911 non-null  int32
#  8   State             293911 non-null  int32
#  9   Zipcode           293911 non-null  float64
#  10  Country           293911 non-null  int32
#  11  Age               293911 non-null  float64
#  12  Gender            293911 non-null  int32
#  13  Income            293911 non-null  int32
#  14  Customer_Segment  293911 non-null  int32
#  15  Date              293911 non-null  datetime64[ns]
# ...

# %%
dataset
# Out:
#         First_name  Last_name  Transaction_ID  Customer_ID  Email       Phone  \
# 0              487       3340       8691788.0      37249.0  16389  1414786801
# 1              383       3491       2174773.0      69749.0  34896  6852899987
# 2              585       4106       6679610.0      30192.0  44610  8362160449
# 3              351       6310       7232460.0      62101.0  35231  2776751724
# 4              182       1797       4983775.0      27901.0   9522  9098267635
# ...            ...        ...             ...          ...    ...         ...
# 302005         472       2614       4246475.0      12104.0  12019  7466353743
# 302006         465        713       1197603.0      69772.0  24031  5754304957
# 302007         165       5233       7743242.0      28449.0  10524  9382530370
# 302008         525       9159       9301950.0      45477.0  41199  9373222023
# 302009         206       6078       2882826.0      53626.0  51869  9518926645
#
# ...

# %%
dataset.describe()
# Out:
#           First_name      Last_name  Transaction_ID    Customer_ID  \
# count  293911.000000  293911.000000    2.939110e+05  293911.000000
# mean      352.531093    5014.223591    5.493726e+06   55013.400523
# min         0.000000       0.000000    1.000007e+06   10000.000000
# 25%       176.000000    2822.000000    3.245886e+06   32470.000000
# 50%       355.000000    5241.000000    5.495879e+06   55027.000000
# 75%       512.000000    7505.000000    7.738197e+06   77514.000000
# max       694.000000    9287.000000    9.999995e+06   99999.000000
# std       197.625328    2762.790459    2.596086e+06   26009.435811
#
#                Email              Phone        Address           City  \
# count  293911.000000           293911.0  293911.000000  293911.000000
# mean    26673.284389  5500607077.126644  145804.176230      63.007475
# min         0.000000       1000049414.0       0.000000       0.000000
# 25%     13762.000000       3253497020.0   72901.000000      26.000000
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler

# %%
df = pd.DataFrame(dataset) 
df
# Out:
#         First_name  Last_name  Transaction_ID  Customer_ID  Email       Phone  \
# 0              487       3340       8691788.0      37249.0  16389  1414786801
# 1              383       3491       2174773.0      69749.0  34896  6852899987
# 2              585       4106       6679610.0      30192.0  44610  8362160449
# 3              351       6310       7232460.0      62101.0  35231  2776751724
# 4              182       1797       4983775.0      27901.0   9522  9098267635
# ...            ...        ...             ...          ...    ...         ...
# 302005         472       2614       4246475.0      12104.0  12019  7466353743
# 302006         465        713       1197603.0      69772.0  24031  5754304957
# 302007         165       5233       7743242.0      28449.0  10524  9382530370
# 302008         525       9159       9301950.0      45477.0  41199  9373222023
# 302009         206       6078       2882826.0      53626.0  51869  9518926645
#
# ...

# %%
features = ['Income', 'Total_Purchases', 'Ratings']

# %%
scaler = StandardScaler()
X = scaler.fit_transform(df[features])

# %%
wcss = []
for i in range(1, 11):
    kmeans = KMeans(n_clusters=i, init='k-means++', random_state=42)
    kmeans.fit(X)
    wcss.append(kmeans.inertia_)

# %%
plt.figure(figsize=(8, 6))
plt.plot(range(1, 11), wcss)
plt.title('Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.show()

# %%
kmeans = KMeans(n_clusters=4, init='k-means++', random_state=42)
y_kmeans = kmeans.fit_predict(X)

# %% [markdown]
# # **Visualization of customer segments**

# %%
plt.figure(figsize=(10, 8))
plt.scatter(X[y_kmeans == 0, 0], X[y_kmeans == 0, 1], s=50, c='red', label='Cluster 1')
plt.scatter(X[y_kmeans == 1, 0], X[y_kmeans == 1, 1], s=50, c='blue', label='Cluster 2')
plt.scatter(X[y_kmeans == 2, 0], X[y_kmeans == 2, 1], s=50, c='green', label='Cluster 3')
plt.scatter(X[y_kmeans == 3, 0], X[y_kmeans == 3, 1], s=50, c='yellow', label='Cluster 4')
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], s=100, c='black', label='Centroids')
plt.title('Customer Segments')
plt.xlabel('Income')
plt.ylabel('Total Purchases')
plt.legend()
plt.show()
